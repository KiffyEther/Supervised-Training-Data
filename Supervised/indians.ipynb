# %%
import pandas as pd
df = pd.read_csv("indians.csv")
df.head()
target = df.Number
inputs = df.drop('Number', axis ='columns')
inputs.columns[inputs.isna().any()]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)
len(X_train)
len(X_test)
len(inputs)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
model.score(X_test,y_test)
X_test[:10]
y_test[:10]
model.predict(X_test[:10])
model.predict_proba(X_test[:10])
# Out:
# array([[9.20344408e-02, 2.40090787e-01, 1.92893936e-01, 1.03479531e-01,
#         1.70282036e-01, 1.12524008e-01, 3.08692044e-02, 1.63220947e-02,
#         5.79155790e-03, 1.63895475e-02, 1.70426444e-02, 1.93489497e-04,
#         1.94258240e-03, 1.44140205e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.52778868e-01, 4.42835453e-01, 1.98136287e-01, 7.78183289e-02,
#         3.59811710e-02, 6.37233083e-02, 1.09021072e-02, 6.64446208e-03,
#         3.77524448e-03, 5.72930032e-03, 5.07261186e-04, 8.32176748e-06,
#         1.15988646e-03, 7.84137143e-10, 0.00000000e+00, 0.00000000e+00],
#        [3.91736279e-02, 2.87697791e-01, 3.30643989e-01, 1.29586280e-01,
#         1.06203529e-01, 6.63789352e-02, 2.93884249e-02, 2.40124926e-03,
#         1.27751974e-03, 2.40993008e-03, 4.69098493e-03, 2.42375852e-08,
#         1.47713417e-04, 1.06265158e-09, 0.00000000e+00, 0.00000000e+00],
#        [2.96868110e-02, 2.88202645e-01, 3.02506555e-01, 1.19706560e-01,
#         1.64307104e-01, 4.98144393e-02, 2.87666679e-02, 5.01378062e-03,
#         2.10076629e-03, 1.73579640e-03, 8.11733685e-03, 1.72905098e-09,
#         4.12908280e-05, 2.45455258e-07, 0.00000000e+00, 0.00000000e+00],
#        [4.62511158e-02, 2.59578722e-01, 3.30981626e-01, 1.69000654e-01,
#         4.69078895e-02, 6.35255026e-02, 5.08339274e-02, 7.28244442e-03,
#         3.68224182e-03, 1.39383853e-03, 2.00843623e-02, 4.50929963e-07,
#         4.77001436e-04, 2.22722909e-07, 0.00000000e+00, 0.00000000e+00],
#        [7.89625506e-03, 5.31827467e-03, 2.09106043e-02, 4.14144806e-03,
#         1.99912832e-02, 1.45291683e-01, 2.83325574e-01, 2.05221134e-02,
#         1.36348251e-01, 1.12249417e-01, 1.86266450e-01, 1.28358160e-03,
#         5.62181594e-02, 2.36904797e-04, 0.00000000e+00, 0.00000000e+00],
#        [8.94847341e-02, 2.06722140e-01, 3.28533552e-01, 1.68733355e-01,
#         1.55195457e-01, 1.59367631e-03, 4.11936618e-02, 2.75068716e-03,
#         7.90396345e-04, 4.76920617e-04, 4.52312579e-03, 2.25430912e-06,
#         3.04223880e-08, 9.42280536e-09, 0.00000000e+00, 0.00000000e+00],
#        [1.91001891e-02, 9.75080069e-03, 1.66203545e-02, 3.71720889e-03,
#         1.07813870e-02, 1.10472273e-01, 3.04572912e-01, 3.52499080e-02,
#         2.70834473e-01, 1.61889798e-01, 1.99965475e-02, 2.41297724e-03,
#         3.46010886e-02, 8.18319605e-08, 0.00000000e+00, 0.00000000e+00],
#        [2.88178231e-01, 1.81887322e-01, 3.35615988e-03, 1.23196122e-01,
#         1.57641081e-03, 3.32696984e-03, 7.69789857e-03, 5.66423009e-02,
#         3.27161037e-01, 6.96736006e-03, 7.12372819e-07, 6.83830015e-08,
#         9.40776585e-06, 9.13660502e-16, 0.00000000e+00, 0.00000000e+00],
#        [2.12170513e-02, 1.71235692e-01, 1.94655006e-01, 9.89993451e-02,
#         1.92329568e-01, 1.63792624e-01, 6.16749046e-02, 2.75516150e-02,
#         1.35352773e-02, 1.29980060e-02, 3.38602666e-02, 1.60928393e-06,
#         7.27147240e-03, 8.77561429e-04, 0.00000000e+00, 0.00000000e+00]])
